# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import plotly

import chart_studio.plotly as py
import warnings
import plotly.graph_objs as go

# %%
dataset = pd.read_excel("Datasets\BEIJE _ Data Analytics & BI Intern Assignment - Dataset1.xlsx",
                       parse_dates = True)
dataset.head()
# Out:
#                   Date  Number of Sales  Subscription Sales  \
# 0           March 2021             4339                4186
# 1           April 2021             7006                6370
# 2  2021-05-01 00:00:00             7637                6832
# 3            June 2021             8131                7785
# 4            July 2021             8333                7907
#
#    Daily Pad (Package of 10)  Daily Pad (Package of 30)  \
# 0                        489                        441
# 1                        717                        791
# 2                        773                        899
# 3                        861                        973
# 4                        843                        974
#
#    Daily Pad (Package of 50)  Normal Pad (Package of 10)  \
# 0                        438                         643
# 1                        576                         831
# 2                        571                         734
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                              0
# Number of Sales                   0
# Subscription Sales                0
# Daily Pad (Package of 10)         0
# Daily Pad (Package of 30)         0
# Daily Pad (Package of 50)         0
# Normal Pad (Package of 10)        0
# Normal Pad (Package of 30)        0
# Normal Pad (Package of 50)        0
# Super Pad (Package of 10)         0
# Super Pad (Package of 30)         0
# Super Pad (Package of 50)         0
# Super+ Pad (Package of 10)        3
# Super+ Pad (Package of 30)        3
# Super+ Pad (Package of 50)        3
# Normal Tampon (Package of 10)     2
# Normal Tampon (Package of 20)     2
# Normal Tampon (Package of 30)     2
# Super Tampon (Package of 10)      2
# Super Tampon (Package of 20)      2
# Super Tampon (Package of 20).1    2
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            19 non-null     object
#  1   Number of Sales                 19 non-null     int64
#  2   Subscription Sales              19 non-null     int64
#  3   Daily Pad (Package of 10)       19 non-null     int64
#  4   Daily Pad (Package of 30)       19 non-null     int64
#  5   Daily Pad (Package of 50)       19 non-null     int64
#  6   Normal Pad (Package of 10)      19 non-null     int64
#  7   Normal Pad (Package of 30)      19 non-null     int64
#  8   Normal Pad (Package of 50)      19 non-null     int64
#  9   Super Pad (Package of 10)       19 non-null     int64
#  10  Super Pad (Package of 30)       19 non-null     int64
#  11  Super Pad (Package of 50)       19 non-null     int64
# ...

# %%
dataset.dropna(axis = "index", inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 3 to 18
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            16 non-null     object
#  1   Number of Sales                 16 non-null     int64
#  2   Subscription Sales              16 non-null     int64
#  3   Daily Pad (Package of 10)       16 non-null     int64
#  4   Daily Pad (Package of 30)       16 non-null     int64
#  5   Daily Pad (Package of 50)       16 non-null     int64
#  6   Normal Pad (Package of 10)      16 non-null     int64
#  7   Normal Pad (Package of 30)      16 non-null     int64
#  8   Normal Pad (Package of 50)      16 non-null     int64
#  9   Super Pad (Package of 10)       16 non-null     int64
#  10  Super Pad (Package of 30)       16 non-null     int64
#  11  Super Pad (Package of 50)       16 non-null     int64
# ...

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'], errors='ignore')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 3 to 18
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            16 non-null     datetime64[ns]
#  1   Number of Sales                 16 non-null     int64
#  2   Subscription Sales              16 non-null     int64
#  3   Daily Pad (Package of 10)       16 non-null     int64
#  4   Daily Pad (Package of 30)       16 non-null     int64
#  5   Daily Pad (Package of 50)       16 non-null     int64
#  6   Normal Pad (Package of 10)      16 non-null     int64
#  7   Normal Pad (Package of 30)      16 non-null     int64
#  8   Normal Pad (Package of 50)      16 non-null     int64
#  9   Super Pad (Package of 10)       16 non-null     int64
#  10  Super Pad (Package of 30)       16 non-null     int64
#  11  Super Pad (Package of 50)       16 non-null     int64
# ...

# %%
from prophet import Prophet
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8), dpi=100)
plt.plot(dataset['Date'], dataset['Number of Sales'])
plt.title('Pageview')
plt.xlabel('Date')
plt.ylabel('Number of Sales')
plt.show()

# %%
m = Prophet()

# %%
numberofsales = dataset[["Date", "Number of Sales"]]

# %%
numberofsales = numberofsales.rename({"Date":"ds", "Number of Sales":"y"}, axis=1)

# %%
numberofsales
# Out:
#            ds      y
# 3  2021-06-01   8131
# 4  2021-07-01   8333
# 5  2021-08-01  10784
# 6  2021-09-01  11195
# 7  2021-10-01  11807
# 8  2021-11-01  12289
# 9  2021-12-01  17968
# 10 2022-01-01  20728
# 11 2022-02-01  22022
# 12 2022-03-01  27745
# 13 2022-04-01  26939
# 14 2022-05-01  25529
# 15 2022-06-01  26304
# 16 2022-07-01  26366
# 17 2022-08-01  30165
# 18 2022-09-01  34459

# %%
m.fit(numberofsales)
# Out:
# 23:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=4, freq='M', include_history=True)

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#            ds          yhat    yhat_lower    yhat_upper
# 15 2022-09-01  33156.265655  30583.530194  35973.343852
# 16 2022-09-30  34819.095710  32070.262411  37542.189263
# 17 2022-10-31  36596.603700  33684.748848  39612.096002
# 18 2022-11-30  38316.772722  35599.585298  40904.969876
# 19 2022-12-31  40094.280712  37295.222790  42636.054641

# %%
m = Prophet()
dailypackage10 = dataset[["Date", "Daily Pad (Package of 10)"]]
dailypackage10 = dailypackage10.rename({"Date":"ds", "Daily Pad (Package of 10)":"y"}, axis=1)
m.fit(dailypackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 22:56:55 - cmdstanpy - INFO - Chain [1] start processing
# 22:56:55 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  2535.946074  2305.201020  2750.355267
# 15 2022-09-01  2666.135609  2427.175501  2909.087727
# 16 2022-09-30  2787.925818  2560.519891  3029.464610
# 17 2022-10-31  2918.115353  2691.473695  3156.117456
# 18 2022-11-30  3044.105225  2806.608771  3269.756837

# %%
m = Prophet()
dailypackage30 = dataset[["Date", "Daily Pad (Package of 30)"]]
dailypackage30 = dailypackage30.rename({"Date":"ds", "Daily Pad (Package of 30)":"y"}, axis=1)
m.fit(dailypackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:22:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:43 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  3619.371007  3290.361238  3975.806782
# 15 2022-09-01  3820.096434  3474.192469  4155.299871
# 16 2022-09-30  4007.871834  3677.166855  4351.138025
# 17 2022-10-31  4208.597262  3880.564567  4547.571849
# 18 2022-11-30  4402.847676  4070.007453  4763.222342

# %%
m = Prophet()
dailypackage50 = dataset[["Date", "Daily Pad (Package of 50)"]]
dailypackage50 = dailypackage50.rename({"Date":"ds", "Daily Pad (Package of 50)":"y"}, axis=1)
m.fit(dailypackage50)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:22:34 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:34 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  1976.100210  1730.970661  2224.082133
# 15 2022-09-01  2081.301280  1842.916238  2317.593674
# 16 2022-09-30  2179.715184  1955.954863  2433.112085
# 17 2022-10-31  2284.916254  2048.550238  2518.257028
# 18 2022-11-30  2386.723741  2147.637611  2617.456771

# %%
m = Prophet()
normalpadpackage10 = dataset[["Date", "Normal Pad (Package of 10)"]]
normalpadpackage10 = normalpadpackage10.rename({"Date":"ds", "Normal Pad (Package of 10)":"y"}, axis=1)
m.fit(normalpadpackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:15 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  2693.124686  2494.800622  2886.590341
# 15 2022-09-01  2840.164956  2642.544222  3034.926664
# 16 2022-09-30  2977.718756  2769.235593  3177.018239
# 17 2022-10-31  3124.759025  2915.852877  3334.847614
# 18 2022-11-30  3267.056060  3051.059297  3462.210154

# %%
m = Prophet()
normalpadpackage30 = dataset[["Date", "Normal Pad (Package of 30)"]]
normalpadpackage30 = normalpadpackage30.rename({"Date":"ds", "Normal Pad (Package of 30)":"y"}, axis=1)
m.fit(normalpadpackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:22:02 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:02 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  4724.407604  4311.317213  5091.452700
# 15 2022-09-01  4998.511169  4619.991671  5382.116641
# 16 2022-09-30  5254.930633  4865.117516  5659.299843
# 17 2022-10-31  5529.034198  5101.956501  5917.886962
# 18 2022-11-30  5794.295712  5404.210049  6186.149343

# %%
m = Prophet()
normalpadpackage50 = dataset[["Date", "Normal Pad (Package of 50)"]]
normalpadpackage50 = normalpadpackage50.rename({"Date":"ds", "Normal Pad (Package of 50)":"y"}, axis=1)
m.fit(normalpadpackage50)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:21:50 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  2706.295608  2261.569392  3106.581649
# 15 2022-09-01  2838.338595  2474.833257  3231.813455
# 16 2022-09-30  2961.862680  2553.793713  3365.716903
# 17 2022-10-31  3093.905667  2667.152553  3494.065507
# 18 2022-11-30  3221.689203  2846.891403  3624.298833

# %%
m = Prophet()
superpadpackage10 = dataset[["Date", "Super Pad (Package of 10)"]]
superpadpackage10 = superpadpackage10.rename({"Date":"ds", "Super Pad (Package of 10)":"y"}, axis=1)
m.fit(superpadpackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:23:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:04 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  3106.266819  2875.951660  3336.498133
# 15 2022-09-01  3279.377998  3053.405940  3513.160557
# 16 2022-09-30  3441.320714  3219.848707  3668.343462
# 17 2022-10-31  3614.431893  3400.050312  3829.820746
# 18 2022-11-30  3781.958840  3550.943888  3993.238195

# %%
m = Prophet()
superpadpackage30 = dataset[["Date", "Super Pad (Package of 30)"]]
superpadpackage30 = superpadpackage30.rename({"Date":"ds", "Super Pad (Package of 30)":"y"}, axis=1)
m.fit(superpadpackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:58 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  3073.274555  2703.049988  3433.470777
# 15 2022-09-01  3241.356842  2883.315222  3623.675515
# 16 2022-09-30  3398.595110  3008.777060  3771.780944
# 17 2022-10-31  3566.677397  3216.780165  3951.421524
# 18 2022-11-30  3729.337674  3363.904610  4109.474590

# %%
m = Prophet()
superpadpackage50 = dataset[["Date", "Super Pad (Package of 50)"]]
superpadpackage50 = superpadpackage50.rename({"Date":"ds", "Super Pad (Package of 50)":"y"}, axis=1)
m.fit(superpadpackage50)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:24:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:24:16 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  1101.677276   697.448836  1500.233426
# 15 2022-09-01  1206.283394   811.792087  1621.698620
# 16 2022-09-30  1304.140731   918.109855  1714.479464
# 17 2022-10-31  1408.746849   995.246493  1820.996029
# 18 2022-11-30  1509.978576  1116.114712  1897.007017

# %%
m = Prophet()
superpluspadpackage10 = dataset[["Date", "Super+ Pad (Package of 10)"]]
superpluspadpackage10 = superpluspadpackage10.rename({"Date":"ds", "Super+ Pad (Package of 10)":"y"}, axis=1)
m.fit(superpluspadpackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:26:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:26:20 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  1524.292422  1384.079321  1666.682638
# 15 2022-09-01  1625.406844  1489.313373  1764.973465
# 16 2022-09-30  1719.997756  1572.692791  1865.947359
# 17 2022-10-31  1821.112178  1677.358139  1963.406087
# 18 2022-11-30  1918.964844  1783.683051  2060.554876

# %%
m = Prophet()
superpluspadpackage30 = dataset[["Date", "Super+ Pad (Package of 30)"]]
superpluspadpackage30 = superpluspadpackage30.rename({"Date":"ds", "Super+ Pad (Package of 30)":"y"}, axis=1)
m.fit(superpluspadpackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:26:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:26:24 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 14 2022-08-01  1310.681768  1133.892133  1476.835634
# 15 2022-09-01  1396.631995  1232.850126  1549.219413
# 16 2022-09-30  1477.037047  1317.937496  1639.205863
# 17 2022-10-31  1562.987274  1392.567815  1735.850459
# 18 2022-11-30  1646.164913  1485.492940  1810.216958

# %%
m = Prophet()
superpluspadpackage50 = dataset[["Date", "Super+ Pad (Package of 50)"]]
superpluspadpackage50 = superpluspadpackage50.rename({"Date":"ds", "Super+ Pad (Package of 50)":"y"}, axis=1)
m.fit(superpluspadpackage50)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:26:28 - cmdstanpy - INFO - Chain [1] start processing
# 00:26:28 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower   yhat_upper
# 14 2022-08-01  707.464444  531.229400   881.143436
# 15 2022-09-01  750.092793  587.442569   900.646795
# 16 2022-09-30  789.970925  640.698839   949.623148
# 17 2022-10-31  832.599274  663.181187   982.399571
# 18 2022-11-30  873.852515  713.104419  1038.926975

# %%
m = Prophet()
normaltamponpackage10 = dataset[["Date", "Normal Tampon (Package of 10)"]]
normaltamponpackage10 = normaltamponpackage10.rename({"Date":"ds", "Normal Tampon (Package of 10)":"y"}, axis=1)
m.fit(normaltamponpackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:28:13 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:13 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 14 2022-08-01  337.958043  286.928189  390.202036
# 15 2022-09-01  358.653148  306.303006  408.115444
# 16 2022-09-30  378.013086  324.930485  424.333114
# 17 2022-10-31  398.708191  349.604345  446.591483
# 18 2022-11-30  418.735713  369.119997  465.327144

# %%
m = Prophet()
normaltamponpackage20 = dataset[["Date", "Normal Tampon (Package of 20)"]]
normaltamponpackage20 = normaltamponpackage20.rename({"Date":"ds", "Normal Tampon (Package of 20)":"y"}, axis=1)
m.fit(normaltamponpackage20)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:29:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:29:24 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 14 2022-08-01  178.798291  157.277189  201.619749
# 15 2022-09-01  188.273280  165.576211  212.424879
# 16 2022-09-30  197.136979  172.854301  218.717997
# 17 2022-10-31  206.611968  184.442153  229.840580
# 18 2022-11-30  215.781311  192.063912  238.176592

# %%
m = Prophet()
normaltamponpackage30 = dataset[["Date", "Normal Tampon (Package of 30)"]]
normaltamponpackage30 = normaltamponpackage30.rename({"Date":"ds", "Normal Tampon (Package of 30)":"y"}, axis=1)
m.fit(normaltamponpackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:30:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:30:04 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 14 2022-08-01   88.269519   65.505031  108.670465
# 15 2022-09-01   93.890287   70.099746  115.094242
# 16 2022-09-30   99.148425   78.537453  120.656654
# 17 2022-10-31  104.769193   82.568304  126.992900
# 18 2022-11-30  110.208645   88.337144  133.891007

# %%
m = Prophet()
supertamponpackage10 = dataset[["Date", "Super Tampon (Package of 10)"]]
supertamponpackage10 = supertamponpackage10.rename({"Date":"ds", "Super Tampon (Package of 10)":"y"}, axis=1)
m.fit(supertamponpackage10)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:31:34 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:34 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 14 2022-08-01  196.894328  162.085235  231.135290
# 15 2022-09-01  209.417485  173.528302  244.823102
# 16 2022-09-30  221.132697  188.596943  253.039622
# 17 2022-10-31  233.655854  199.697494  268.274103
# 18 2022-11-30  245.775039  211.177892  280.643881

# %%
m = Prophet()
supertamponpackage20 = dataset[["Date", "Super Tampon (Package of 20)"]]
supertamponpackage20 = supertamponpackage20.rename({"Date":"ds", "Super Tampon (Package of 20)":"y"}, axis=1)
m.fit(supertamponpackage20)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:33:01 - cmdstanpy - INFO - Chain [1] start processing
# 00:33:01 - cmdstanpy - INFO - Chain [1] done processing
#            ds       yhat  yhat_lower  yhat_upper
# 14 2022-08-01  76.066698   66.493072   85.938614
# 15 2022-09-01  80.266018   70.510056   90.131483
# 16 2022-09-30  84.194415   73.931097   94.270111
# 17 2022-10-31  88.393735   78.211470   98.245731
# 18 2022-11-30  92.457593   81.997492  102.029235

# %%
m = Prophet()
supertamponpackage30 = dataset[["Date", "Super Tampon (Package of 30)"]]
supertamponpackage30 = supertamponpackage30.rename({"Date":"ds", "Super Tampon (Package of 30)":"y"}, axis=1)
m.fit(supertamponpackage30)
future = m.make_future_dataframe(periods=3, freq='M', include_history=True)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 00:33:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:33:44 - cmdstanpy - INFO - Chain [1] done processing
#            ds       yhat  yhat_lower  yhat_upper
# 17 2022-08-01  51.706556   41.563943   62.373904
# 18 2022-09-01  54.574650   43.718498   65.585175
# 19 2022-09-30  57.257706   47.100439   68.460681
# 20 2022-10-31  60.125801   49.065750   70.964080
# 21 2022-11-30  62.901376   51.640048   73.395081

# %% [markdown]
# ## BEIJE 2022 Ekim Ayında Sipariş Edilmesi Beklenen Ürün Miktarı
# Kasım ayında beklenen en fazla
# - Satış miktarı(Number of Sales) 39612,
# - Daily Pad (Package of 10) 3156 adet,
# - Daily Pad (Package of 30) 4547 adet,
# - Daily Pad (Package of 50) 2518 adet,
# - Normal Pad (Package of 10) 3334 adet,
# - Normal Pad (Package of 30) 5917 adet,
# - Normal Pad (Package of 50) 3494 adet,
# - Super Pad (Package of 10) 3829 adet,
# - Super Pad (Package of 30) 3951 adet,
# - Super Pad (Package of 50) 1820 adet,
# - Super+ Pad (Package of 10) 1963 adet,
# - Super+ Pad (Package of 30) 1735 adet,
# - Super+ Pad (Package of 50) 982 adet,
# - Normal Tampon (Package of 10) 446 adet,
# - Normal Tampon (Package of 20) 229 adet,
# - Normal Tampon (Package of 30) 126 adet,
# - Super Tampon (Package of 10) 268 adet,
# - Super Tampon (Package of 20) 98 adet,
# - Super Tampon (Package of 30) 70 adet.
