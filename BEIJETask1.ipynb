# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel("Datasets\BEIJE _ Data Analytics & BI Intern Assignment - Dataset.xlsx")
dataset.head()
# Out:
#                          responseID  yas  Günlük_Ped  Ped  Tampon  Kap  süre  \
# 0  jtg5skm1u00svftb78p3ijtg5skgzyig   25  Günlük Ped  Ped     NaN  NaN     7
# 1  1xhbr0y1ikcxgt7s8js1xhbr0yod9kcf   34         NaN  Ped     NaN  NaN     5
# 2  fjjorx1l62888wco4cbfjjorx1ebs54t   22  Günlük Ped  Ped     NaN  NaN     5
# 3  nju1klq8s7ggcvqrzbb9axnju1klb192   34  Günlük Ped  Ped     NaN  NaN     7
# 4  g21ewx3nbgirs5wg21e7pnkjpqsdccat   34         NaN  Ped  Tampon  NaN     6
#
#    döngü_süresi  Gün_1      Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 0            35   Orta  Çok yoğun  ...      NaN           NaN         NaN
# 1            28  Hafif       Orta  ...      NaN           NaN         NaN
# 2            28   Orta      Yoğun  ...      0.0           0.0         0.0
# 3            29  Hafif       Orta  ...      3.0           NaN         NaN
# 4            21   Orta  Çok yoğun  ...      1.0           NaN         NaN
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   responseID         203 non-null    object
#  1   yas                203 non-null    int64
#  2   Günlük_Ped         151 non-null    object
#  3   Ped                198 non-null    object
#  4   Tampon             21 non-null     object
#  5   Kap                6 non-null      object
#  6   süre               203 non-null    int64
#  7   döngü_süresi       203 non-null    int64
#  8   Gün_1              197 non-null    object
#  9   Gün_2              200 non-null    object
#  10  Gün_3              198 non-null    object
#  11  Gün_4              192 non-null    object
#  12  Gün_5              164 non-null    object
#  13  Gün_6              100 non-null    object
#  14  Gün_7              40 non-null     object
#  15  Gün_8              13 non-null     object
# ...

# %%
yas_ortalaması = dataset.yas.sum()/203
yas_ortalaması
# Out:
# 29.55665024630542

# %%
dongu_sure_ortalaması = dataset.döngü_süresi.sum()/203
dongu_sure_ortalaması
# Out:
# 27.31527093596059

# %%
regl_sure = dataset.süre.sum()/203
regl_sure
# Out:
# 5.615763546798029

# %%
dataset.Günlük_Ped.count()
# Out:
# 151

# %%
# Günlük Ped kullananların yüzdesi
151*100/203
# Out:
# 74.38423645320196

# %%
dataset.Ped.count()
# Out:
# 198

# %%
# Ped kullananların yüzdesi
198*100/203
# Out:
# 97.53694581280789

# %%
dataset.Tampon.count()
# Out:
# 21

# %%
# Tampon kullananların yüzdesi
21*100/203
# Out:
# 10.344827586206897

# %%
dataset.Kap.count()
# Out:
# 6

# %%
# Kap kullananların yüzdesi
6*100/203
# Out:
# 2.955665024630542

# %%
ürünler = ["Günlük Ped", "Ped", "Tampon", "Kap"]

fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [dataset.Günlük_Ped.count(), dataset.Ped.count(), dataset.Tampon.count(), dataset.Kap.count()], color ='wheat', width = 0.4)
plt.xlabel("Ürünler")
plt.ylabel("Kişi Sayısı")
plt.title("Ankete Katılan Kullanıcıların Ürün Tercihleri")
plt.show()

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"] == "Ped") & (dataset["Tampon"] == "Tampon") & (dataset["Kap"] == "Kap")]
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 118  e6c32w84bn67vaia83yc0be6c3q3ydze   29  Günlük Ped  Ped  Tampon  Kap
#
#      süre  döngü_süresi  Gün_1  Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 118     4             4  Yoğun  Yoğun  ...      NaN           5.0         NaN
#
#     Hergün  Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped istek_ped  \
# 118    NaN  Regl sonu ve başı             2.0              NaN       Ped
#
#      istek_tampon  istek_kap
# 118        Tampon        Kap
#
# [1 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"] == "Ped") & (dataset["Tampon"] == "Tampon") & (dataset["Kap"].isnull())]
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 10   quajcdwxpx1ldtzpquajss28rtbmi2m4   25  Günlük Ped  Ped  Tampon  NaN
# 14   qkbmm0e96r6l8daf4eaqkbmm8jrothr5   24  Günlük Ped  Ped  Tampon  NaN
# 19   kn0ahq52j5hfvxtl3biq1kn0aht18fe0   23  Günlük Ped  Ped  Tampon  NaN
# 33   2awkem2t6ucro6yqcoj2awkxe27rjci6   26  Günlük Ped  Ped  Tampon  NaN
# 35   5hlh1gsyxme065hlhiuilwy6a8pziemq   40  Günlük Ped  Ped  Tampon  NaN
# 62   33bf38ez552zgbjfv1u0333bf387d2ui   25  Günlük Ped  Ped  Tampon  NaN
# 63   43lhxvkqvymr6g9y43lhhj3ne9gmv0ql   40  Günlük Ped  Ped  Tampon  NaN
# 84   6eiiqwag6yhgp3z6ei30ov1jz7bd2jyc   40  Günlük Ped  Ped  Tampon  NaN
# 90   qq5f9yya1yordp6om2qq5fjr3ejl1z1f   38  Günlük Ped  Ped  Tampon  NaN
# 99   wdk33chm6igg0xn5c12wdk33ch9rx33r   22  Günlük Ped  Ped  Tampon  NaN
# 109  d3t3z3dfuq0y736wfyapd3t3zxzewy52   25  Günlük Ped  Ped  Tampon  NaN
# 111  anzuh2exy3fs4ud2vtsanzuh2dxm7inn   25  Günlük Ped  Ped  Tampon  NaN
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"] == "Ped") & (dataset["Tampon"].isnull()) & (dataset["Kap"] == "Kap")]
# Out:
#                            responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 23   ea33qgb2ii8upxh8oqoea33qgbbc1sd6   21  Günlük Ped  Ped    NaN  Kap     6
# 32   8pb50s9ssj3genmuv8pb500axtejdieg   25  Günlük Ped  Ped    NaN  Kap     5
# 177  nf9x3opu9ciyka6f8fd5nf9x3opu9puw   37  Günlük Ped  Ped    NaN  Kap     5
#
#      döngü_süresi  Gün_1  Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 23             29  Yoğun  Yoğun  ...      0.0           0.0         0.0
# 32             30  Hafif  Yoğun  ...      0.0           0.0         0.0
# 177            29  Hafif  Yoğun  ...      NaN           NaN         NaN
#
#       Hergün  Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped istek_ped  \
# 23       NaN  Regl sonu ve başı             2.0       Günlük Ped       Ped
# 32   Her gün                NaN             1.0       Günlük Ped       NaN
# 177  Her gün                NaN             1.0              NaN       NaN
#
#      istek_tampon  istek_kap
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"].isnull()) & (dataset["Tampon"] == "Tampon") & (dataset["Kap"] == "Kap")]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"] == "Ped") & (dataset["Tampon"] == "Tampon") & (dataset["Kap"] == "Kap")]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"] == "Ped") & (dataset["Tampon"].isnull()) & (dataset["Kap"].isnull())]
# Out:
#                            responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 0    jtg5skm1u00svftb78p3ijtg5skgzyig   25  Günlük Ped  Ped    NaN  NaN     7
# 2    fjjorx1l62888wco4cbfjjorx1ebs54t   22  Günlük Ped  Ped    NaN  NaN     5
# 3    nju1klq8s7ggcvqrzbb9axnju1klb192   34  Günlük Ped  Ped    NaN  NaN     7
# 5    2razrkujwpi5pifkgkk2razrfiipknm3   45  Günlük Ped  Ped    NaN  NaN     7
# 6    uavip8l04dbmz2agt2fuavipgcx5s6t2   22  Günlük Ped  Ped    NaN  NaN     6
# ..                                ...  ...         ...  ...    ...  ...   ...
# 195  kanb1zleoek1nmekanb1c8yflkwx8zp9   24  Günlük Ped  Ped    NaN  NaN     6
# 197  9ljp0fbe10f8n9ljp5vf2lo2dvrsww39   21  Günlük Ped  Ped    NaN  NaN     6
# 198  mdunkqyhvaorhbmdz3g3z6zatjgj88bz   23  Günlük Ped  Ped    NaN  NaN     5
# 201  zep0pnljl1l8t2zhijbzep08at2nri3n   20  Günlük Ped  Ped    NaN  NaN     5
# 202  qry5jjoy0smqmrqun4i8tvqry5jovq6z   28  Günlük Ped  Ped    NaN  NaN     5
#
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"].isnull()) & (dataset["Tampon"] == "Tampon") & (dataset["Kap"].isnull())]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"] == "Ped") & (dataset["Tampon"] == "Tampon") & (dataset["Kap"].isnull())]
# Out:
#                            responseID  yas Günlük_Ped  Ped  Tampon  Kap  süre  \
# 4    g21ewx3nbgirs5wg21e7pnkjpqsdccat   34        NaN  Ped  Tampon  NaN     6
# 8    8r1odcdr9koumihyc8r1odcemnbd2kmw   24        NaN  Ped  Tampon  NaN     6
# 26   vc0ro5ql9gobgpx140zvc0ro6dxbje3l   33        NaN  Ped  Tampon  NaN     6
# 105  pnwlia7n3wicjub4ip1wpnwlia5m0tkm   19        NaN  Ped  Tampon  NaN     7
#
#      döngü_süresi      Gün_1      Gün_2  ... Gece_Ped Normal_Tampon  \
# 4              21       Orta  Çok yoğun  ...      1.0           NaN
# 8              30  Çok yoğun  Çok yoğun  ...      NaN           NaN
# 26             33      Hafif       Orta  ...      1.0           NaN
# 105            25      Hafif  Çok yoğun  ...      1.0           NaN
#
#     Gece_Tampon Hergün Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped  \
# 4           NaN    NaN               NaN             NaN              NaN
# 8           NaN    NaN               NaN             NaN       Günlük Ped
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"].isnull()) & (dataset["Tampon"].isnull()) & (dataset["Kap"] == "Kap")]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"] == "Ped") & (dataset["Tampon"].isnull()) & (dataset["Kap"] == "Kap")]
# Out:
#                            responseID  yas Günlük_Ped  Ped Tampon  Kap  süre  \
# 146  u102exdjjria7dibau1029npuzk56vo1   35        NaN  Ped    NaN  Kap     4
# 162  xs2i9z34kv7b3dvmkxs2i90yoy8gy9j8   38        NaN  Ped    NaN  Kap     4
#
#      döngü_süresi  Gün_1  Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 146            28  Yoğun  Yoğun  ...      1.0           NaN         NaN
# 162            27  Hafif  Yoğun  ...      1.0           NaN         NaN
#
#     Hergün Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped istek_ped  \
# 146    NaN               NaN             NaN              NaN       Ped
# 162    NaN               NaN             NaN              NaN       Ped
#
#      istek_tampon  istek_kap
# 146           NaN        Kap
# 162           NaN        NaN
#
# [2 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"].isnull()) & (dataset["Tampon"] == "Tampon") & (dataset["Kap"] == "Kap")]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"] == "Günlük Ped") & (dataset["Ped"].isnull()) & (dataset["Tampon"].isnull()) & (dataset["Kap"].isnull())]
# Out:
#                            responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 29   14u0rypdn3q673m14f2np5js2fvbrulb   56  Günlük Ped  NaN    NaN  NaN     1
# 77   6slc97filof6e2z6slc92fl5l7mq64bq   27  Günlük Ped  NaN    NaN  NaN     7
# 138  l10b4e4shc3lml10o69hk2eyc12lo69h   27  Günlük Ped  NaN    NaN  NaN     5
# 170  yldqtn2079nr73myldqzrcbycpuzauys   49  Günlük Ped  NaN    NaN  NaN     2
# 185  i5rwbv264lraao5hecyhi5rwbujlw9hk   24  Günlük Ped  NaN    NaN  NaN     3
#
#      döngü_süresi  Gün_1      Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 29              0    NaN        NaN  ...      NaN           NaN         NaN
# 77              7   Orta  Çok yoğun  ...      1.0           NaN         NaN
# 138            28    NaN        NaN  ...      NaN           NaN         NaN
# 170             3  Hafif      Hafif  ...      NaN           NaN         NaN
# 185            28  Yoğun       Orta  ...      NaN           NaN         NaN
#
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"] == "Ped") & (dataset["Tampon"].isnull()) & (dataset["Kap"].isnull())]
# Out:
#                            responseID  yas Günlük_Ped  Ped Tampon  Kap  süre  \
# 1    1xhbr0y1ikcxgt7s8js1xhbr0yod9kcf   34        NaN  Ped    NaN  NaN     5
# 7    6y2plcyv1b3e36bayj6c6y2plcygrwy8   43        NaN  Ped    NaN  NaN     7
# 9    q5u6l3pdc3jpkguq5n3qq5u6l36vdk01   22        NaN  Ped    NaN  NaN     6
# 11   ev4hnmd22g7hqhevoao8729w3kdtvu11   25        NaN  Ped    NaN  NaN     4
# 28   5v0hx1vcpcqh5jlcwbp8lt5v0hx1v7cd   36        NaN  Ped    NaN  NaN     5
# 34   g23hgharyupjjdkqlg23hghvru4fr7we   15        NaN  Ped    NaN  NaN     5
# 39   lhxblesytqjauwqi5gllhx5ow41t7nh8   30        NaN  Ped    NaN  NaN     6
# 40   zjwfooj2y68jlv9zjwfoyr8b12cq3okd   22        NaN  Ped    NaN  NaN     6
# 44   lau76qb9rio4h8u83r5jmlau7665ls16   22        NaN  Ped    NaN  NaN     7
# 45   rihzdbe8ct30u435ch4vjerihzdbe8pf   21        NaN  Ped    NaN  NaN     4
# 46   w83tnv82kt4ikgsipw83tnvo13cb22x7   21        NaN  Ped    NaN  NaN     6
# ...

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"].isnull()) & (dataset["Tampon"] == "Tampon") & (dataset["Kap"].isnull())]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"].isnull()) & (dataset["Tampon"].isnull()) & (dataset["Kap"] == "Kap")]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["Ped"].isnull()) & (dataset["Tampon"].isnull()) & (dataset["Kap"].isnull())]
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
günlükped_hergün = dataset.Hergün.count()
günlükped_hergün
# Out:
# 86

# %%
günlükped_regl_sonu_ve_basi = dataset.Regl_sonu_ve_basi.count()
günlükped_regl_sonu_ve_basi
# Out:
# 74

# %%
adet_günlük_ped = dataset.adet_günlük_ped.count()
adet_günlük_ped
# Out:
# 150

# %%
ortalama_günlük_ped_adedi = dataset.adet_günlük_ped.sum()/150
ortalama_günlük_ped_adedi
# Out:
# 2.4266666666666667

# %%
yas_20den_küçük = (dataset.loc[dataset["yas"]<20])
yas_20den_küçük
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 16   hnp1zw8bowsopglp2hnp1xz77xme6ock   16  Günlük Ped  Ped     NaN  NaN
# 18   u8j46logo7af9w7vcig9u8j4auruvhid   19  Günlük Ped  Ped     NaN  NaN
# 20   ldnrn229ymo9k88y7r93ldnrn2o3gh71   19  Günlük Ped  Ped     NaN  NaN
# 30   mqds42d7tg6g98l9mmqdsh6kfgp39oaz   14  Günlük Ped  Ped     NaN  NaN
# 34   g23hgharyupjjdkqlg23hghvru4fr7we   15         NaN  Ped     NaN  NaN
# 59   vk8c8ii1xyk9ugfydavk8maaoq1k8gxg   19         NaN  Ped     NaN  NaN
# 85   62x2jat6y27buwcm90ft9662x2jatgqr   19  Günlük Ped  Ped     NaN  NaN
# 92   yhyvop9gpp5c30d05tyhyvopvbqdc583   19         NaN  Ped     NaN  NaN
# 105  pnwlia7n3wicjub4ip1wpnwlia5m0tkm   19         NaN  Ped  Tampon  NaN
# 121  tq7wbqpo3v5e7qz2y2ej5fzt5itq7wbq   19  Günlük Ped  Ped     NaN  NaN
# 167  1o2nflknhj61eyjz1o2nft4wjixlln30   18         NaN  Ped     NaN  NaN
#
#      süre  döngü_süresi  Gün_1      Gün_2  ... Gece_Ped Normal_Tampon  \
# ...

# %%
yas_20_30_arası = dataset.loc[(dataset["yas"]>=20) & (dataset["yas"]<30)]
yas_20_30_arası
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 0    jtg5skm1u00svftb78p3ijtg5skgzyig   25  Günlük Ped  Ped     NaN  NaN
# 2    fjjorx1l62888wco4cbfjjorx1ebs54t   22  Günlük Ped  Ped     NaN  NaN
# 6    uavip8l04dbmz2agt2fuavipgcx5s6t2   22  Günlük Ped  Ped     NaN  NaN
# 8    8r1odcdr9koumihyc8r1odcemnbd2kmw   24         NaN  Ped  Tampon  NaN
# 9    q5u6l3pdc3jpkguq5n3qq5u6l36vdk01   22         NaN  Ped     NaN  NaN
# ..                                ...  ...         ...  ...     ...  ...
# 197  9ljp0fbe10f8n9ljp5vf2lo2dvrsww39   21  Günlük Ped  Ped     NaN  NaN
# 198  mdunkqyhvaorhbmdz3g3z6zatjgj88bz   23  Günlük Ped  Ped     NaN  NaN
# 199  hfca6k48hhni1u9gn5b30hfca6kl5ym0   26         NaN  Ped     NaN  NaN
# 201  zep0pnljl1l8t2zhijbzep08at2nri3n   20  Günlük Ped  Ped     NaN  NaN
# 202  qry5jjoy0smqmrqun4i8tvqry5jovq6z   28  Günlük Ped  Ped     NaN  NaN
#
#      süre  döngü_süresi      Gün_1      Gün_2  ... Gece_Ped Normal_Tampon  \
# ...

# %%
yas_30_40_arası = dataset.loc[(dataset["yas"]>=30) & (dataset["yas"]<40)]
yas_30_40_arası
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 1    1xhbr0y1ikcxgt7s8js1xhbr0yod9kcf   34         NaN  Ped     NaN  NaN
# 3    nju1klq8s7ggcvqrzbb9axnju1klb192   34  Günlük Ped  Ped     NaN  NaN
# 4    g21ewx3nbgirs5wg21e7pnkjpqsdccat   34         NaN  Ped  Tampon  NaN
# 12   vpovmnrx8j16acsq1u0avpovmfj5cf1h   33  Günlük Ped  Ped     NaN  NaN
# 15   y2onw0wcxm902oaome9edzy2onwm8vb0   30  Günlük Ped  Ped     NaN  NaN
# 21   0fsb6nuirrw1lpoob0fsb6qupigksc6l   39  Günlük Ped  Ped     NaN  NaN
# 26   vc0ro5ql9gobgpx140zvc0ro6dxbje3l   33         NaN  Ped  Tampon  NaN
# 27   8rg7njenqk5sh1bi58rg7n29auis9ilt   34  Günlük Ped  Ped     NaN  NaN
# 28   5v0hx1vcpcqh5jlcwbp8lt5v0hx1v7cd   36         NaN  Ped     NaN  NaN
# 31   vunqbr8zqew68186awcvunqbrc0ux0n4   32  Günlük Ped  Ped     NaN  NaN
# 37   esm4qydw1360cnh5c4aebbgquvcesm4q   31  Günlük Ped  Ped     NaN  NaN
# 39   lhxblesytqjauwqi5gllhx5ow41t7nh8   30         NaN  Ped     NaN  NaN
# ...

# %%
yas_40_50_arası = dataset.loc[(dataset["yas"]>=40) & (dataset["yas"]<50)]
yas_40_50_arası
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 5    2razrkujwpi5pifkgkk2razrfiipknm3   45  Günlük Ped  Ped     NaN  NaN
# 7    6y2plcyv1b3e36bayj6c6y2plcygrwy8   43         NaN  Ped     NaN  NaN
# 35   5hlh1gsyxme065hlhiuilwy6a8pziemq   40  Günlük Ped  Ped  Tampon  NaN
# 36   05euwczs5o5b30a05eux701c8devrerh   40  Günlük Ped  Ped     NaN  NaN
# 48   ykjnt9xvgz2jpc67tiynykjnt9mraxt1   40         NaN  Ped     NaN  NaN
# 63   43lhxvkqvymr6g9y43lhhj3ne9gmv0ql   40  Günlük Ped  Ped  Tampon  NaN
# 67   w7xsc6fs5txlmy3yidjw7xscidyeitpt   40         NaN  Ped     NaN  NaN
# 74   rabp0m7elaa5vv1grabmlyjbd0oy6wfz   41  Günlük Ped  Ped     NaN  NaN
# 79   at7gnmvwtlcifmdg8at7gn51ku6qhhxp   42  Günlük Ped  Ped     NaN  NaN
# 84   6eiiqwag6yhgp3z6ei30ov1jz7bd2jyc   40  Günlük Ped  Ped  Tampon  NaN
# 86   2wstwgzmki8wgeflrcux42wstwg84h3g   49  Günlük Ped  Ped     NaN  NaN
# 88   274mjgjqs50o57j71vdp274miuw8sdmj   42  Günlük Ped  Ped     NaN  NaN
# ...

# %%
yas_50_60_arası = dataset.loc[(dataset["yas"]>=50) & (dataset["yas"]<60)]
yas_50_60_arası
# Out:
#                           responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 29  14u0rypdn3q673m14f2np5js2fvbrulb   56  Günlük Ped  NaN    NaN  NaN     1
#
#     döngü_süresi Gün_1 Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon   Hergün  \
# 29             0   NaN   NaN  ...      NaN           NaN         NaN  Her gün
#
#    Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped istek_ped  istek_tampon  \
# 29               NaN             2.0       Günlük Ped       NaN           NaN
#
#     istek_kap
# 29        NaN
#
# [1 rows x 30 columns]

# %%
yas_60_70_arası = dataset.loc[(dataset["yas"]>=60) & (dataset["yas"]<70)]
yas_60_70_arası
# Out:
# Empty DataFrame
# Columns: [responseID, yas, Günlük_Ped, Ped, Tampon, Kap, süre, döngü_süresi, Gün_1, Gün_2, Gün_3, Gün_4, Gün_5, Gün_6, Gün_7, Gün_8, Gün_9, Gün_10, Normal_Ped, Uzun_Ped, Gece_Ped, Normal_Tampon, Gece_Tampon, Hergün, Regl_sonu_ve_basi, adet_günlük_ped, istek_günlük_ped, istek_ped, istek_tampon, istek_kap]
# Index: []
#
# [0 rows x 30 columns]

# %%
kisi_sayısı_20den_kücük = yas_20den_küçük.responseID.count()
kisi_sayısı_2030 = yas_20_30_arası.responseID.count()
kisi_sayısı_3040 = yas_30_40_arası.responseID.count()
kisi_sayısı_4050 = yas_40_50_arası.responseID.count()
kisi_sayısı_5060 = yas_50_60_arası.responseID.count()

# Kullanıcı yaş dağılımı
yoğunluk = ["20'den küçük", "20-30 arası", "30-40 arası", "40-50 arası", "50-60 arası"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [kisi_sayısı_20den_kücük, kisi_sayısı_2030, kisi_sayısı_3040, kisi_sayısı_4050, kisi_sayısı_5060], color ='wheat', width = 0.4)
plt.xlabel("Yaş Aralığı")
plt.ylabel("Kişi Sayısı")
plt.title("Ankete Katılan Kullanıcıların Yaş Dağılımı")
plt.show()

# %%
dataset2 = dataset.loc[(dataset["Hergün"] == "Her gün")]
hergün_günlük_ped_ortalaması = dataset2.adet_günlük_ped.sum()/86
hergün_günlük_ped_ortalaması
# Out:
# 2.395348837209302

# %%
Gün1 = dataset.Gün_1
Gün1
# Out:
# 0       Orta
# 1      Hafif
# 2       Orta
# 3      Hafif
# 4       Orta
#        ...
# 198     Orta
# 199    Hafif
# 200    Hafif
# 201    Yoğun
# 202    Yoğun
# Name: Gün_1, Length: 203, dtype: object

# %%
Gün1_bool = (Gün1.isnull())
yok_Gün1 = Gün1_bool.sum()
yok_Gün1
# Out:
# 6

# %%
yok_Gün1_yüzdesi = yok_Gün1*100/203
yok_Gün1_yüzdesi
# Out:
# 2.955665024630542

# %%
Gün1_bool = (Gün1 == "Hafif")
Gün1_bool.sum()
# Out:
# 78

# %%
Gün1_bool = (Gün1 == "Hafif")
hafif_Gün1 = Gün1_bool.sum()

# %%
hafif_Gün1_yüzdesi = hafif_Gün1*100/203
hafif_Gün1_yüzdesi
# Out:
# 38.423645320197046

# %%
Gün1_bool = (Gün1 == "Orta")
orta_Gün1 = Gün1_bool.sum()
orta_Gün1
# Out:
# 55

# %%
orta_Gün1_yüzdesi = orta_Gün1*100/203
orta_Gün1_yüzdesi
# Out:
# 27.0935960591133

# %%
Gün1_bool = (Gün1 == "Yoğun")
yoğun_Gün1 = Gün1_bool.sum()
yoğun_Gün1
# Out:
# 40

# %%
yoğun_Gün1_yüzdesi = yoğun_Gün1*100/203
yoğun_Gün1_yüzdesi
# Out:
# 19.704433497536947

# %%
Gün1_bool = (Gün1 == "Çok yoğun")
çokyoğun_Gün1 = Gün1_bool.sum()
çokyoğun_Gün1
# Out:
# 24

# %%
çokyoğun_Gün1_yüzdesi = çokyoğun_Gün1*100/203
çokyoğun_Gün1_yüzdesi
# Out:
# 11.822660098522167

# %%
Gün2 = dataset.Gün_2
Gün2
# Out:
# 0      Çok yoğun
# 1           Orta
# 2          Yoğun
# 3           Orta
# 4      Çok yoğun
#          ...
# 198        Yoğun
# 199        Yoğun
# 200         Orta
# 201    Çok yoğun
# 202        Yoğun
# Name: Gün_2, Length: 203, dtype: object

# %%
Gün2_bool = (Gün2.isnull())
yok_Gün2 = Gün2_bool.sum()
yok_Gün2
# Out:
# 3

# %%
yok_Gün2_yüzdesi = yok_Gün2*100/203
yok_Gün2_yüzdesi
# Out:
# 1.477832512315271

# %%
Gün2_bool = (Gün2 == "Hafif")
hafif_Gün2 = Gün2_bool.sum()
hafif_Gün2
# Out:
# 10

# %%
hafif_Gün2_yüzdesi = hafif_Gün2*100/203
hafif_Gün2_yüzdesi
# Out:
# 4.926108374384237

# %%
Gün2_bool = (Gün2 == "Orta")
orta_Gün2 = Gün2_bool.sum()
orta_Gün2
# Out:
# 31

# %%
orta_Gün2_yüzdesi = orta_Gün2*100/203
orta_Gün2_yüzdesi
# Out:
# 15.270935960591133

# %%
Gün2_bool = (Gün2 == "Yoğun")
yoğun_Gün2 = Gün2_bool.sum()
yoğun_Gün2
# Out:
# 100

# %%
yoğun_Gün2_yüzdesi = yoğun_Gün2*100/203
yoğun_Gün2_yüzdesi
# Out:
# 49.26108374384236

# %%
Gün2_bool = (Gün2 == "Çok yoğun")
çokyoğun_Gün2 = Gün2_bool.sum()
çokyoğun_Gün2
# Out:
# 59

# %%
çokyoğun_Gün2_yüzdesi = çokyoğun_Gün2*100/203
çokyoğun_Gün2_yüzdesi
# Out:
# 29.064039408866996

# %%
Gün3 = dataset.Gün_3
Gün3
# Out:
# 0      Çok yoğun
# 1          Yoğun
# 2           Orta
# 3      Çok yoğun
# 4          Yoğun
#          ...
# 198         Orta
# 199        Yoğun
# 200         Orta
# 201        Yoğun
# 202         Orta
# Name: Gün_3, Length: 203, dtype: object

# %%
Gün3_bool = (Gün3.isnull())
yok_Gün3 = Gün3_bool.sum()
yok_Gün3
# Out:
# 5

# %%
yok_Gün3_yüzdesi = yok_Gün3*100/203
yok_Gün3_yüzdesi
# Out:
# 2.4630541871921183

# %%
Gün3_bool = (Gün3 == "Hafif")
hafif_Gün3 = Gün3_bool.sum()
hafif_Gün3
# Out:
# 14

# %%
hafif_Gün3_yüzdesi = hafif_Gün3*100/203
hafif_Gün3_yüzdesi
# Out:
# 6.896551724137931

# %%
Gün3_bool = (Gün3 == "Orta")
orta_Gün3 = Gün3_bool.sum()
orta_Gün3
# Out:
# 79

# %%
orta_Gün3_yüzdesi = orta_Gün3*100/203
orta_Gün3_yüzdesi
# Out:
# 38.916256157635466

# %%
Gün3_bool = (Gün3 == "Yoğun")
yoğun_Gün3 = Gün3_bool.sum()
yoğun_Gün3
# Out:
# 78

# %%
yoğun_Gün3_yüzdesi = yoğun_Gün3*100/203
yoğun_Gün3_yüzdesi
# Out:
# 38.423645320197046

# %%
Gün3_bool = (Gün3 == "Çok yoğun")
çokyoğun_Gün3 = Gün3_bool.sum()
çokyoğun_Gün3
# Out:
# 27

# %%
çokyoğun_Gün3_yüzdesi = çokyoğun_Gün3*100/203
çokyoğun_Gün3_yüzdesi
# Out:
# 13.300492610837438

# %%
Gün4 = dataset.Gün_4
Gün4
# Out:
# 0           Orta
# 1           Orta
# 2          Hafif
# 3      Çok yoğun
# 4          Yoğun
#          ...
# 198         Orta
# 199         Orta
# 200         Orta
# 201         Orta
# 202        Hafif
# Name: Gün_4, Length: 203, dtype: object

# %%
Gün4_bool = (Gün4.isnull())
yok_Gün4 = Gün4_bool.sum()
yok_Gün4
# Out:
# 11

# %%
yok_Gün4_yüzdesi = yok_Gün4*100/203
yok_Gün4_yüzdesi
# Out:
# 5.41871921182266

# %%
Gün4_bool = (Gün4 == "Hafif")
hafif_Gün4 = Gün4_bool.sum()
hafif_Gün4
# Out:
# 80

# %%
hafif_Gün4_yüzdesi = hafif_Gün4*100/203
hafif_Gün4_yüzdesi
# Out:
# 39.40886699507389

# %%
Gün4_bool = (Gün4 == "Orta")
orta_Gün4 = Gün4_bool.sum()
orta_Gün4
# Out:
# 83

# %%
orta_Gün4_yüzdesi = orta_Gün4*100/203
orta_Gün4_yüzdesi
# Out:
# 40.88669950738916

# %%
Gün4_bool = (Gün4 == "Yoğun")
yoğun_Gün4 = Gün4_bool.sum()
yoğun_Gün4
# Out:
# 25

# %%
yoğun_Gün4_yüzdesi = yoğun_Gün4*100/203
yoğun_Gün4_yüzdesi
# Out:
# 12.31527093596059

# %%
Gün4_bool = (Gün4 == "Çok yoğun")
çokyoğun_Gün4 = Gün4_bool.sum()
çokyoğun_Gün4
# Out:
# 4

# %%
çokyoğun_Gün4_yüzdesi = çokyoğun_Gün4*100/203
çokyoğun_Gün4_yüzdesi
# Out:
# 1.9704433497536946

# %%
Gün5 = dataset.Gün_5
Gün5
# Out:
# 0      Hafif
# 1      Hafif
# 2      Hafif
# 3      Yoğun
# 4       Orta
#        ...
# 198    Hafif
# 199    Hafif
# 200    Hafif
# 201    Hafif
# 202    Hafif
# Name: Gün_5, Length: 203, dtype: object

# %%
Gün5_bool = (Gün5.isnull())
yok_Gün5 = Gün5_bool.sum()
yok_Gün5
# Out:
# 39

# %%
yok_Gün5_yüzdesi = yok_Gün5*100/203
yok_Gün5_yüzdesi
# Out:
# 19.211822660098523

# %%
Gün5_bool = (Gün5 == "Hafif")
hafif_Gün5 = Gün5_bool.sum()
hafif_Gün5
# Out:
# 132

# %%
hafif_Gün5_yüzdesi = hafif_Gün5*100/203
hafif_Gün5_yüzdesi
# Out:
# 65.02463054187191

# %%
Gün5_bool = (Gün5 == "Orta")
orta_Gün5 = Gün5_bool.sum()
orta_Gün5
# Out:
# 23

# %%
orta_Gün5_yüzdesi = orta_Gün5*100/203
orta_Gün5_yüzdesi
# Out:
# 11.330049261083744

# %%
Gün5_bool = (Gün5 == "Yoğun")
yoğun_Gün5 = Gün5_bool.sum()
yoğun_Gün5
# Out:
# 7

# %%
yoğun_Gün5_yüzdesi = yoğun_Gün5*100/203
yoğun_Gün5_yüzdesi
# Out:
# 3.4482758620689653

# %%
Gün5_bool = (Gün5 == "Çok yoğun")
çokyoğun_Gün5 = Gün5_bool.sum()
çokyoğun_Gün5
# Out:
# 2

# %%
çokyoğun_Gün5_yüzdesi = çokyoğun_Gün5*100/203
çokyoğun_Gün5_yüzdesi
# Out:
# 0.9852216748768473

# %%
Gün6 = dataset.Gün_6
Gün6
# Out:
# 0      Hafif
# 1        NaN
# 2        NaN
# 3      Hafif
# 4      Hafif
#        ...
# 198      NaN
# 199      NaN
# 200    Hafif
# 201      NaN
# 202      NaN
# Name: Gün_6, Length: 203, dtype: object

# %%
Gün6_bool = (Gün6.isnull())
yok_Gün6 = Gün6_bool.sum()
yok_Gün6
# Out:
# 103

# %%
yok_Gün6_yüzdesi = yok_Gün6*100/203
yok_Gün6_yüzdesi
# Out:
# 50.73891625615764

# %%
Gün6_bool = (Gün6 == "Hafif")
hafif_Gün6 = Gün6_bool.sum()
hafif_Gün6
# Out:
# 91

# %%
hafif_Gün6_yüzdesi = hafif_Gün6*100/203
hafif_Gün6_yüzdesi
# Out:
# 44.827586206896555

# %%
Gün6_bool = (Gün6 == "Orta")
orta_Gün6 = Gün6_bool.sum()
orta_Gün6
# Out:
# 8

# %%
orta_Gün6_yüzdesi = orta_Gün6*100/203
orta_Gün6_yüzdesi
# Out:
# 3.9408866995073892

# %%
Gün6_bool = (Gün6 == "Yoğun")
yoğun_Gün6 = Gün6_bool.sum()
yoğun_Gün6
# Out:
# 1

# %%
yoğun_Gün6_yüzdesi = yoğun_Gün6*100/203
yoğun_Gün6_yüzdesi
# Out:
# 0.49261083743842365

# %%
Gün6_bool = (Gün6 == "Çok yoğun")
çokyoğun_Gün6 = Gün6_bool.sum()
çokyoğun_Gün6
# Out:
# 0

# %%
çokyoğun_Gün6_yüzdesi = çokyoğun_Gün6*100/203
çokyoğun_Gün6_yüzdesi
# Out:
# 0.0

# %%
# 1. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün1, hafif_Gün1, orta_Gün1, yoğun_Gün1, çokyoğun_Gün1], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 1. Günü Yoğunluk Dağılımı")
plt.show()

# %%
# 2. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün2, hafif_Gün2, orta_Gün2, yoğun_Gün2, çokyoğun_Gün2], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 2. Günü Yoğunluk Dağılımı")
plt.show()

# %%
# 3. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün3, hafif_Gün3, orta_Gün3, yoğun_Gün3, çokyoğun_Gün3], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 3. Günü Yoğunluk Dağılımı")
plt.show()

# %%
# 4. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün4, hafif_Gün4, orta_Gün4, yoğun_Gün4, çokyoğun_Gün4], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 4. Günü Yoğunluk Dağılımı")
plt.show()

# %%
# 5. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün5, hafif_Gün5, orta_Gün5, yoğun_Gün5, çokyoğun_Gün5], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 5. Günü Yoğunluk Dağılımı")
plt.show()

# %%
# 6. regl günü yoğunluk dağılımı
yoğunluk = ["Yok", "Hafif", "Orta", "Yoğun", "Çok Yoğun"]

fig = plt.figure(figsize = (10, 5))
plt.bar(yoğunluk, [yok_Gün6, hafif_Gün6, orta_Gün6, yoğun_Gün6, çokyoğun_Gün6], color ='wheat', width = 0.4)
 
plt.xlabel("Yoğunluk")
plt.ylabel("Kişi Sayısı")
plt.title("Regl Döneminin 6. Günü Yoğunluk Dağılımı")
plt.show()

# %%
normal_ped_kullanımı = dataset.Normal_Ped.count()
print(normal_ped_kullanımı)
# Out:
# 175

# %%
normal_ped_kullanımı_ortalaması = dataset.Normal_Ped.sum()/normal_ped_kullanımı
normal_ped_kullanımı_ortalaması
# Out:
# 2.6285714285714286

# %%
uzun_ped_kullanımı = dataset.Uzun_Ped.count()
print(uzun_ped_kullanımı)
# Out:
# 159

# %%
uzun_ped_kullanımı_ortalaması = dataset.Uzun_Ped.sum()/uzun_ped_kullanımı
uzun_ped_kullanımı_ortalaması
# Out:
# 2.018867924528302

# %%
gece_ped_kullanımı = dataset.Gece_Ped.count()
print(gece_ped_kullanımı)
# Out:
# 119

# %%
gece_ped_kullanımı_ortalaması = dataset.Gece_Ped.sum()/gece_ped_kullanımı
gece_ped_kullanımı_ortalaması
# Out:
# 1.3445378151260505

# %%
normal_tampon_kullanımı = dataset.Normal_Tampon.count()
print(normal_tampon_kullanımı)
# Out:
# 60

# %%
normal_tampon_kullanımı_ortalaması = dataset.Normal_Tampon.sum()/normal_tampon_kullanımı
normal_tampon_kullanımı_ortalaması
# Out:
# 0.26666666666666666

# %%
gece_tampon_kullanımı = dataset.Gece_Tampon.count()
print(gece_tampon_kullanımı)
# Out:
# 57

# %%
gece_tampon_kullanımı_ortalaması = dataset.Gece_Tampon.sum()/gece_tampon_kullanımı
gece_tampon_kullanımı_ortalaması
# Out:
# 0.12280701754385964

# %%
# Regl döneminde ürün kullanım dağılımı
ürünler = ["Normal Ped", "Uzun Ped", "Gece Ped", "Normal Tampon", "Gece Tampon"]

fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [normal_tampon_kullanımı, uzun_ped_kullanımı, gece_ped_kullanımı, normal_tampon_kullanımı, gece_tampon_kullanımı], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("Regl Döneminde Kullanılan Ürün Tercihleri")
plt.show()

# %%
# Regl döneminde ürün kullanım ortalamaları
ürünler = ["Normal Ped", "Uzun Ped", "Gece Ped", "Normal Tampon", "Gece Tampon"]

fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [normal_tampon_kullanımı_ortalaması, uzun_ped_kullanımı_ortalaması, gece_ped_kullanımı_ortalaması, normal_tampon_kullanımı_ortalaması, gece_tampon_kullanımı_ortalaması], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("Bir Regl Döneminde Kullanılan Ürün Ortalamaları")
plt.show()

# %%
# 20 yaşından küçük kullanıcıların ürün tercihleri
ürün_tercihi_20den_kücük = dataset.loc[(dataset["yas"]<20)].iloc[:,2:6]
ürün_tercihi_20den_kücük.count()
# Out:
# Günlük_Ped     6
# Ped           11
# Tampon         1
# Kap            0
# dtype: int64

# %%
ürünler = ["Günlük Ped", "Ped", "Tampon", "Kap"]
  
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [ürün_tercihi_20den_kücük.Günlük_Ped.count(), ürün_tercihi_20den_kücük.Ped.count(), ürün_tercihi_20den_kücük.Tampon.count(), ürün_tercihi_20den_kücük.Kap.count()], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("20 Yaşından Küçük Kullanıcıların Ürün Tercihi")
plt.show()

# %%
# 20 30 yaş arası ürün tercihi
ürün_tercihi_2030 = dataset.loc[(dataset["yas"]>=20) & (dataset["yas"]<30)].iloc[:,2:6]
ürün_tercihi_2030.count()
# Out:
# Günlük_Ped     86
# Ped           109
# Tampon         11
# Kap             3
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [ürün_tercihi_2030.Günlük_Ped.count(), ürün_tercihi_2030.Ped.count(), ürün_tercihi_2030.Tampon.count(), ürün_tercihi_2030.Kap.count()], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("20 30 Yaş Arası Kullanıcıların Ürün Tercihi")
plt.show()

# %%
# 30 40 yaş arası ürün tercihi
ürün_tercihi_3040 = dataset.loc[(dataset["yas"]>=30) & (dataset["yas"]<40)].iloc[:,2:6]
ürün_tercihi_3040.count()
# Out:
# Günlük_Ped    34
# Ped           50
# Tampon         5
# Kap            3
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [ürün_tercihi_3040.Günlük_Ped.count(), ürün_tercihi_3040.Ped.count(), ürün_tercihi_3040.Tampon.count(), ürün_tercihi_3040.Kap.count()], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("30 40 Yaş Arası Kullanıcıların Ürün Tercihi")
plt.show()

# %%
# 40 50 yaş arası ürün tercihi
ürün_tercihi_4050 = dataset.loc[(dataset["yas"]>=40) & (dataset["yas"]<50)].iloc[:,2:6]
ürün_tercihi_4050.count()
# Out:
# Günlük_Ped    24
# Ped           28
# Tampon         4
# Kap            0
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [ürün_tercihi_4050.Günlük_Ped.count(), ürün_tercihi_4050.Ped.count(), ürün_tercihi_4050.Tampon.count(), ürün_tercihi_4050.Kap.count()], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("40 50 Yaş Arası Kullanıcıların Ürün Tercihi")
plt.show()

# %%
# 50 60 yaş arası ürün tercihi
ürün_tercihi_5060 = dataset.loc[(dataset["yas"]>=50) & (dataset["yas"]<60)].iloc[:,2:6]
ürün_tercihi_5060.count()
# Out:
# Günlük_Ped    1
# Ped           0
# Tampon        0
# Kap           0
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [ürün_tercihi_5060.Günlük_Ped.count(), ürün_tercihi_5060.Ped.count(), ürün_tercihi_5060.Tampon.count(), ürün_tercihi_5060.Kap.count()], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanıcı Sayıları")
plt.title("50 60 Yaş Arası Kullanıcıların Ürün Tercihi")
plt.show()

# %%
# Günlük ped kullanmayıp kullanmak isteyenler
dataset.loc[(dataset["Günlük_Ped"].isnull()) & (dataset["istek_günlük_ped"] == "Günlük Ped")]
# Out:
#                            responseID  yas Günlük_Ped  Ped  Tampon  Kap  süre  \
# 8    8r1odcdr9koumihyc8r1odcemnbd2kmw   24        NaN  Ped  Tampon  NaN     6
# 26   vc0ro5ql9gobgpx140zvc0ro6dxbje3l   33        NaN  Ped  Tampon  NaN     6
# 40   zjwfooj2y68jlv9zjwfoyr8b12cq3okd   22        NaN  Ped     NaN  NaN     6
# 44   lau76qb9rio4h8u83r5jmlau7665ls16   22        NaN  Ped     NaN  NaN     7
# 59   vk8c8ii1xyk9ugfydavk8maaoq1k8gxg   19        NaN  Ped     NaN  NaN     4
# 67   w7xsc6fs5txlmy3yidjw7xscidyeitpt   40        NaN  Ped     NaN  NaN     5
# 113  53r9df4nb9e653r9dlqis9xkvcoe06ei   27        NaN  Ped     NaN  NaN     8
# 122  3t4dnpkl3ux304gi53t4dnvix0ct3cn1   37        NaN  Ped     NaN  NaN     5
# 125  eaayaq25hfkormwcim5weaayaq2sfl5g   20        NaN  Ped     NaN  NaN     6
# 133  b46i1k4xh7yj3ai9b46i1k4yp4tqfaas   26        NaN  Ped     NaN  NaN     5
# 147  bsiqlpxa8z8z7ubsiq9embiguktoni7v   22        NaN  Ped     NaN  NaN     5
# ...

# %%
# Ped kullanmayıp ped kullanmak isteyenler
dataset.loc[(dataset["Ped"].isnull()) & (dataset["istek_ped"] == "Ped")]
# Out:
#                            responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 77   6slc97filof6e2z6slc92fl5l7mq64bq   27  Günlük Ped  NaN    NaN  NaN     7
# 185  i5rwbv264lraao5hecyhi5rwbujlw9hk   24  Günlük Ped  NaN    NaN  NaN     3
#
#      döngü_süresi  Gün_1      Gün_2  ... Gece_Ped Normal_Tampon Gece_Tampon  \
# 77              7   Orta  Çok yoğun  ...      1.0           NaN         NaN
# 185            28  Yoğun       Orta  ...      NaN           NaN         NaN
#
#       Hergün Regl_sonu_ve_basi adet_günlük_ped istek_günlük_ped istek_ped  \
# 77   Her gün               NaN             4.0              NaN       Ped
# 185  Her gün               NaN             3.0       Günlük Ped       Ped
#
#      istek_tampon  istek_kap
# 77            NaN        NaN
# 185           NaN        NaN
#
# [2 rows x 30 columns]

# %%
#  Tampon kullanmayıp tampon kullanmak isteyenler
dataset.loc[(dataset["Tampon"].isnull()) & (dataset["istek_tampon"] == "Tampon")]
# Out:
#                            responseID  yas  Günlük_Ped  Ped Tampon  Kap  süre  \
# 27   8rg7njenqk5sh1bi58rg7n29auis9ilt   34  Günlük Ped  Ped    NaN  NaN     5
# 51   yq5vorgolgytxflzje7yq5vorg4yj8pf   20         NaN  Ped    NaN  NaN     6
# 57   8z0ino7rw1fnhhcml8z0ieka7ho0364w   28  Günlük Ped  Ped    NaN  NaN     5
# 58   2e0xw21uqnpzekjmqfjoa52e0xw791za   28  Günlük Ped  Ped    NaN  NaN     5
# 67   w7xsc6fs5txlmy3yidjw7xscidyeitpt   40         NaN  Ped    NaN  NaN     5
# 68   jfwsdvb0zaat6kxtjfwt94ye3bmlzmgd   28  Günlük Ped  Ped    NaN  NaN     4
# 70   4x8daz2swwzpscw2dfi14xj965ji8pfy   23  Günlük Ped  Ped    NaN  NaN     7
# 121  tq7wbqpo3v5e7qz2y2ej5fzt5itq7wbq   19  Günlük Ped  Ped    NaN  NaN     7
# 128  iyza6smlzz0xgj8dyyiyza6sh7whs3lk   35  Günlük Ped  Ped    NaN  NaN     4
# 130  84xeeukj6137rtut84xen04rthvw38uv   36  Günlük Ped  Ped    NaN  NaN     5
# 133  b46i1k4xh7yj3ai9b46i1k4yp4tqfaas   26         NaN  Ped    NaN  NaN     5
# ...

# %%
# Kap kullanmayıp kap kullanmak isteyenler
dataset.loc[(dataset["Kap"].isnull()) & (dataset["istek_kap"] == "Kap")]
# Out:
#                            responseID  yas  Günlük_Ped  Ped  Tampon  Kap  \
# 3    nju1klq8s7ggcvqrzbb9axnju1klb192   34  Günlük Ped  Ped     NaN  NaN
# 8    8r1odcdr9koumihyc8r1odcemnbd2kmw   24         NaN  Ped  Tampon  NaN
# 10   quajcdwxpx1ldtzpquajss28rtbmi2m4   25  Günlük Ped  Ped  Tampon  NaN
# 11   ev4hnmd22g7hqhevoao8729w3kdtvu11   25         NaN  Ped     NaN  NaN
# 16   hnp1zw8bowsopglp2hnp1xz77xme6ock   16  Günlük Ped  Ped     NaN  NaN
# 17   jas708zf2sv4w4wfhgjas7m2rykbz9t2   24  Günlük Ped  Ped     NaN  NaN
# 51   yq5vorgolgytxflzje7yq5vorg4yj8pf   20         NaN  Ped     NaN  NaN
# 56   f7fjwqru1s83pd7qoif7fjwqx30wvd8e   25  Günlük Ped  Ped     NaN  NaN
# 57   8z0ino7rw1fnhhcml8z0ieka7ho0364w   28  Günlük Ped  Ped     NaN  NaN
# 61   ymhrwjdk9p4d618kymyzhctwdel2k3mu   24         NaN  Ped     NaN  NaN
# 62   33bf38ez552zgbjfv1u0333bf387d2ui   25  Günlük Ped  Ped  Tampon  NaN
# 65   gceqaq1x5wxrnejxhv49ocgceqaq150m   22  Günlük Ped  Ped     NaN  NaN
# ...

# %%
# Günlük Ped kullanmak isteyenlerin sayısı
günlük_ped_kullanmak_isteyenler = dataset.loc[dataset["istek_günlük_ped"] == "Günlük Ped"].responseID.count()
günlük_ped_kullanmak_isteyenler
# Out:
# 144

# %%
# Ped kullanmak isteyenlerin sayısı
ped_kullanmak_isteyenler = dataset.loc[dataset["istek_ped"] == "Ped"].responseID.count()
ped_kullanmak_isteyenler
# Out:
# 187

# %%
# Tampon kullanmak isteyenlerin sayısı
tampon_kullanmak_isteyenler = dataset.loc[dataset["istek_tampon"] == "Tampon"].responseID.count()
tampon_kullanmak_isteyenler
# Out:
# 30

# %%
#  Kap kullanmak isteyenlerin sayısı
kap_kullanmak_isteyenler = dataset.loc[dataset["istek_kap"] == "Kap"].responseID.count()
kap_kullanmak_isteyenler
# Out:
# 41

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(ürünler, [günlük_ped_kullanmak_isteyenler, ped_kullanmak_isteyenler, tampon_kullanmak_isteyenler, kap_kullanmak_isteyenler], color ='wheat', width = 0.4)
 
plt.xlabel("Ürünler")
plt.ylabel("Kullanmak İsteyen Sayısı")
plt.title("Kullanılmak İstenen Menstrüel Ürün Dağılımı")
plt.show()

# %%
kullanıcı = {"Yaş": input("Lütfen yaşınızı girin:"), 
        "Günlük Ped": input("Günlük Ped kullanıyor musunuz? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "Ped": input("Ped kullanıyor musunuz? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "Tampon": input("Tampon kullanıyor musunuz? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "Kap": input("Kap kullanıyor musunuz? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "Regl Süresi": input("Ortalama regl süreniz kaç gün?"), 
        "Döngü Süresi": input("Ortalama döngü süreniz kaç gün?"), 
        "Gün1": input("Reglinin birinci günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"), 
        "Gün2": input("Reglinin ikinci günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"), 
        "Gün3": input("Reglinin üçüncü günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"), 
        "Gün4": input("Reglinin dördüncü günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"), 
        "Gün5": input("Reglinin beşinci günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"),
        "Gün6": input("Reglinin altıncı günü ne kadar yogun geçiyor? Lütfen 'Yok', 'Hafif', 'Orta', 'Yoğun', 'Çok Yoğun' seçeneklerinden birini gir:"), 
        "Normal Ped": input("Bir regl döenminde ortalama kaç adet normal ped kullanıyorsun?"), 
        "Uzun Ped": input("Bir regl döenminde ortalama kaç adet uzun ped kullanıyorsun?"), 
        "Gece Ped": input("Bir regl döenminde ortalama kaç adet gece ped kullanıyorsun?"), 
        "Normal Tampon": input("Bir regl döenminde ortalama kaç adet normal tampon kullanıyorsun?"),
        "Gece Tampon": input("Bir regl döenminde ortalama kaç adet gece tampon kullanıyorsun?"), 
        "Günlük Ped Kullanımı": input("Günlük pedi ne sıklıkla kullanıyorsun? Lütfen 'Her gün' ya da 'Regl sonu ve başı' cevaplarından birini gir:"), 
        "Günlük Ped Adet": input("Bir günde kaç adet günlük ped kullanıyorsun?"), 
        "İstek Günlük Ped": input("Günlük Ped kullanmak ister misin? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "İstek Ped": input("Ped kullanmak ister misin? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "İstek Tampon": input("Tampon kullanmak ister misin? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:"), 
        "İstek Kap": input("Kap kullanmak ister misin? Lütfen 'Evet' veya 'Hayır' olarak cevaplayınız:")}

# %%
kullanıcı
# Out:
# {'Yaş': '28',
#  'Günlük Ped': 'Evet',
#  'Ped': 'Evet',
#  'Tampon': 'Hayır',
#  'Kap': 'Hayır',
#  'Regl Süresi': '5',
#  'Döngü Süresi': '26',
#  'Gün1': 'Hafif',
#  'Gün2': 'Yoğun',
#  'Gün3': 'Yoğun',
#  'Gün4': 'Orta',
#  'Gün5': 'Hafif',
#  'Gün6': 'Yok',
#  'Normal Ped': '2',
#  'Uzun Ped': '0',
#  'Gece Ped': '1',
#  'Normal Tampon': '0',
#  'Gece Tampon': '0',
#  'Günlük Ped Kullanımı': 'Her gün',
#  'Günlük Ped Adet': '3',
#  'İstek Günlük Ped': 'Evet',
#  'İstek Ped': 'Evet',
#  'İstek Tampon': 'Evet',
#  'İstek Kap': 'Hayır'}

# %%
if int(kullanıcı["Regl Süresi"]) < 6:
    if kullanıcı["Gün1"] == "Yok" or kullanıcı["Gün1"] == "Hafif" or kullanıcı["Gün1"] == "Orta":
        if kullanıcı["Gün2"] == "Yok" or kullanıcı["Gün2"] == "Hafif" or kullanıcı["Gün2"] == "Orta":
            if kullanıcı["Gün3"] == "Yok" or kullanıcı["Gün3"] == "Hafif" or kullanıcı["Gün3"] == "Orta":
                if 21 <= int(kullanıcı["Döngü Süresi"]):
                    print("Girdiğin bilgiler doğrultusunda döngünün hafif olduğunu belirledik!")
                else:
                    print("Girdiğin bilgiler doğrultusunda döngünün hafif olduğunu düşünüyoruz ancak döngü süren ortalamanın altında kalıyor!")
            else: 
                print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")         
        else: 
            print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")             
    else: 
        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!") 

elif int(kullanıcı["Regl Süresi"]) == 6:
    if kullanıcı["Gün1"] == "Hafif" or kullanıcı["Gün1"] == "Orta" or kullanıcı["Gün1"] == "Yoğun":
        if kullanıcı["Gün2"] == "Orta" or kullanıcı["Gün2"] == "Yoğun" or kullanıcı["Gün2"] == "Çok Yoğun":
            if kullanıcı["Gün3"] == "Orta" or kullanıcı["Yoğun"] == "Yoğun" or kullanıcı["Gün3"] == "Çok Yoğun":
                if kullanıcı["Gün4"] == "Hafif" or kullanıcı["Gün4"] == "Orta" or kullanıcı["Gün4"] == "Yoğun":
                    if 21 <= int(kullanıcı["Döngü Süresi"]):
                        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
                    else:
                        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu düşünüyoruz ancak döngü süren ortalamanın altında kalıyor!")
            else: 
                print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
        else: 
            print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")                 
    else: 
        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")

elif int(kullanıcı["Regl Süresi"]) > 6:
    if kullanıcı["Gün1"] == "Orta" or kullanıcı["Gün1"] == "Yoğun" or kullanıcı["Gün1"] == "Çok Yoğun":
        if kullanıcı["Gün2"] == "Orta" or kullanıcı["Gün2"] == "Yoğun" or kullanıcı["Gün2"] == "Çok Yoğun":
            if kullanıcı["Gün3"] == "Orta" or kullanıcı["Gün3"] == "Yoğun" or kullanıcı["Gün3"] == "Çok Yoğun":    
                if kullanıcı["Gün4"] == "Orta" or kullanıcı["Gün4"] == "Yoğun" or kullanıcı["Gün4"] == "Çok Yoğun":
                    if kullanıcı["Gün5"] == "Hafif" or kullanıcı["Gün5"] == "Orta" or kullanıcı["Gün5"] == "Yoğun":    
                        if 21 <= int(kullanıcı["Döngü Süresi"]):
                            print("Girdiğin bilgiler doğrultusunda döngünün yoğun olduğunu belirledik!")
                        else:
                            print("Girdiğin bilgiler doğrultusunda döngünün yoğun olduğunu düşünüyoruz ancak döngü süren ortalamanın altında kalıyor!") 
            else: 
                print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
        else: 
            print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
    else: 
        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")

elif int(kullanıcı["Regl Süresi"]) > 6:
    if kullanıcı["Gün1"] == "Yoğun" or kullanıcı["Gün1"] == "Çok Yoğun":
        if kullanıcı["Gün2"] == "Yoğun" or kullanıcı["Gün2"] == "Çok Yoğun":
            if kullanıcı["Gün3"] == "Yoğun" or kullanıcı["Gün3"] == "Çok Yoğun":    
                if kullanıcı["Gün4"] == "Yoğun" or kullanıcı["Gün4"] == "Çok Yoğun":
                    if kullanıcı["Gün5"] == "Hafif" or kullanıcı["Gün5"] == "Orta" or kullanıcı["Gün5"] == "Yoğun":    
                        if 21 <= int(kullanıcı["Döngü Süresi"]):
                            print("Girdiğin bilgiler doğrultusunda döngünün çok yoğun olduğunu belirledik!")
                        else:
                            print("Girdiğin bilgiler doğrultusunda döngünün çok yoğun olduğunu düşünüyoruz ancak döngü süren ortalamanın altında kalıyor!") 
            else: 
                print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
        else: 
            print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
    else: 
        print("Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!")
# Out:
# Girdiğin bilgiler doğrultusunda döngünün orta olduğunu belirledik!

# %%
def paketöneri(kullanıcı):
    paket = []
    if kullanıcı["Günlük Ped"] == "Evet" and kullanıcı["Günlük Ped Kullanımı"] == "Her gün":
        günlükped = int(kullanıcı["Günlük Ped Adet"])*30
        paket.append(f"{günlükped} adet günlük ped")
        if kullanıcı["Ped"] == "Evet":
            if int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{geceped} adet gece ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")


                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                            
                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")  
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")               
                    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{geceped} adet gece ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    


            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{geceped} adet gece ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                        
                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon") 
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    



            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{uzunped} adet uzun ped", f"{uzunped} adet uzun ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")     

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{geceped} adet gece ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) == 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")  
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{uzunped} adet uzun ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    


            else:
                paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

        elif kullanıcı["Ped"] == "Hayır":
            if kullanıcı["İstek Ped"] == "Evet":
                paket.append(f"{int(normal_ped_kullanımı_ortalaması)} normal ped")
                paket.append(f"{int(uzun_ped_kullanımı_ortalaması)} uzun ped")
                paket.append(f"{int(gece_ped_kullanımı_ortalaması)} gece ped")
                if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            else:
                if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

        else:
            paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
            if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon") 
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

            else:
                if kullanıcı["İstek Tampon"] == "Evet":
                    paket.append("1 adet normal tampon")
                    paket.append("1 adet gece tampon")
                    if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                        paket.append("1 adet kap")
                    elif kullanıcı["Kap"] == "Evet":
                        paket.append("1 adet kap")

                elif kullanıcı["İstek Tampon"] == "Hayır":
                    if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                        paket.append("1 adet kap")
                    elif kullanıcı["Kap"] == "Evet":
                        paket.append("1 adet kap")            

    elif kullanıcı["Günlük Ped"] == "Evet" and kullanıcı["Günlük Ped Kullanımı"] == "Regl sonu ve başı": 
        günlükped = int(kullanıcı["Günlük Ped Adet"])*2
        paket.append(f"{günlükped} adet günlük ped")
        if kullanıcı["Ped"] == "Evet":
            if int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{geceped} adet gece ped")
                
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")  
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{uzunped} adet uzun ped")
                paket.append(f"{geceped} adet gece ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    


            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{geceped} adet gece ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon") 
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                paket.append(f"{uzunped} adet uzun ped", f"{uzunped} adet uzun ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")  
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{geceped} adet gece ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon") 
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) == 0:
                normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{normalped} adet normal ped")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")  
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                paket.append(f"{uzunped} adet uzun ped") 
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon") 
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap") 
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    


            else:
                paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")  
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

        elif kullanıcı["Ped"] == "Hayır":
            if kullanıcı["İstek Ped"] == "Evet":
                paket.append(f"{int(normal_ped_kullanımı_ortalaması)} normal ped")
                paket.append(f"{int(uzun_ped_kullanımı_ortalaması)} uzun ped")
                paket.append(f"{int(gece_ped_kullanımı_ortalaması)} gece ped")
                if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
        else:
            paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
            if kullanıcı["Tampon"] == "Evet":
                    if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                        gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{gecetampon} adet gecetampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                        normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                        paket.append(f"{normaltampon} adet normal tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

                    else:
                        paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
            else:
                if kullanıcı["İstek Tampon"] == "Evet":
                    paket.append("1 adet normal tampon")
                    paket.append("1 adet gece tampon")
                    if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                        paket.append("1 adet kap")
                    elif kullanıcı["Kap"] == "Evet":
                        paket.append("1 adet kap") 

                elif kullanıcı["İstek Tampon"] == "Hayır":
                    if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                        paket.append("1 adet kap")
                    elif kullanıcı["Kap"] == "Evet":
                        paket.append("1 adet kap")    

    else:
        if kullanıcı["İstek Günlük Ped"] == "Evet":
            paket.append(f"{hergün_günlük_ped_ortalaması} adet günlük ped")
            if kullanıcı["Ped"] == "Evet":
                if int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{geceped} adet gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
    
                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    


                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap") 

                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{geceped} adet gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                            
                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    


                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{geceped} adet gece ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")     

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{uzunped} adet uzun ped", f"{uzunped} adet uzun ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{geceped} adet gece ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) == 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")

                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{uzunped} adet uzun ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    


                else:
                    paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

            elif kullanıcı["Ped"] == "Hayır":
                if kullanıcı["İstek Ped"] == "Evet":
                    paket.append(f"{int(normal_ped_kullanımı_ortalaması)} normal ped")
                    paket.append(f"{int(uzun_ped_kullanımı_ortalaması)} uzun ped")
                    paket.append(f"{int(gece_ped_kullanımı_ortalaması)} gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                            if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                                normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                                gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{normaltampon} adet normal tampon")
                                paket.append(f"{gecetampon} adet gecetampon")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                                gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{gecetampon} adet gecetampon")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                                normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{normaltampon} adet normal tampon")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            else:
                                paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")

                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

            else:
                paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")        

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")        

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")        

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")        
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                        paket.append("1 adet normal tampon")
                        paket.append("1 adet gece tampon")
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    
                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")
                        elif kullanıcı["Kap"] == "Evet":
                            paket.append("1 adet kap")    

        elif kullanıcı["İstek Günlük Ped"] == "Hayır" :
            if kullanıcı["Ped"] == "Evet":
                if int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{geceped} adet gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) != 0:
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{uzunped} adet uzun ped")
                    paket.append(f"{geceped} adet gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon") 
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    


                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{geceped} adet gece ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    paket.append(f"{uzunped} adet uzun ped", f"{uzunped} adet uzun ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) != 0:
                    geceped = int(kullanıcı["Gece Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{geceped} adet gece ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) != 0 and int(kullanıcı["Uzun Ped"]) == 0 and int(kullanıcı["Gece Ped"]) == 0:
                    normalped = int(kullanıcı["Normal Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{normalped} adet normal ped")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")  
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                elif int(kullanıcı["Normal Ped"]) == 0 and int(kullanıcı["Uzun Ped"]) != 0 and int(kullanıcı["Gece Ped"]) == 0:
                    uzunped = int(kullanıcı["Uzun Ped"])*int(kullanıcı["Regl Süresi"])
                    paket.append(f"{uzunped} adet uzun ped") 
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    


                else:
                    paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                    if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

            elif kullanıcı["Ped"] == "Hayır":
                if kullanıcı["İstek Ped"] == "Evet":
                    paket.append(f"{int(normal_ped_kullanımı_ortalaması)} normal ped")
                    paket.append(f"{int(uzun_ped_kullanımı_ortalaması)} uzun ped")
                    paket.append(f"{int(gece_ped_kullanımı_ortalaması)} gece ped")
                    if kullanıcı["Tampon"] == "Evet":
                            if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                                normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                                gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{normaltampon} adet normal tampon")
                                paket.append(f"{gecetampon} adet gecetampon")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                                gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{gecetampon} adet gecetampon")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                                normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                                paket.append(f"{normaltampon} adet normal tampon") 
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                            else:
                                paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                                if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                    paket.append("1 adet kap")
                                elif kullanıcı["Kap"] == "Evet":
                                    paket.append("1 adet kap")    

                    else:
                        if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                        elif kullanıcı["İstek Tampon"] == "Hayır":
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
            else:
                paket.append("Ped kullandığını belirtmene rağmen girdiğin herhangi bir ped adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                if kullanıcı["Tampon"] == "Evet":
                        if int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) == 0 and int(kullanıcı["Gece Tampon"]) != 0:
                            gecetampon = int(kullanıcı["Gece Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{gecetampon} adet gecetampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    

                        elif int(kullanıcı["Normal Tampon"]) != 0 and int(kullanıcı["Gece Tampon"]) == 0:
                            normaltampon = int(kullanıcı["Normal Tampon"])*int(kullanıcı["Regl Süresi"])
                            paket.append(f"{normaltampon} adet normal tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
        
                        else:
                            paket.append("Tampon kullandığını belirtmene rağmen girdiğin herhangi bir tampon adedi bulamadık. Bilgilerini kontrol edebilir misin?")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                else:
                    if kullanıcı["İstek Tampon"] == "Evet":
                            paket.append("1 adet normal tampon")
                            paket.append("1 adet gece tampon")
                            if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                                paket.append("1 adet kap")
                            elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")    
                    elif kullanıcı["İstek Tampon"] == "Hayır":
                        if kullanıcı["Kap"] == "Hayır" and kullanıcı["İstek Kap"] == "Evet":
                            paket.append("1 adet kap")       
                        elif kullanıcı["Kap"] == "Evet":
                                paket.append("1 adet kap")
    return paket

# %%
paketöneri(kullanıcı)
# Out:
# ['90 adet günlük ped',
#  '10 adet normal ped',
#  '5 adet gece ped',
#  '1 adet normal tampon',
#  '1 adet gece tampon']
